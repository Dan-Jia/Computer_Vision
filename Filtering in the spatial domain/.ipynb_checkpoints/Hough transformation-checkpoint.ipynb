# %% [markdown]
# # Aufgabe 1: Histogramme
# Das Histogramm $h$ eines Bildes stellt die Verteilung der Intensitäten im Bild dar.
# Schreiben Sie eine Python-Funktion, die ein Grauwertbild lädt, dessen Histogramm ermittelt und dieses graphisch darstellt!

# %% [markdown]
# ## 0. Pfade, Pakete etc.

# %%
import glob
import urllib.request

# %matplotlib notebook
import matplotlib.pyplot as plt

import imageio
import numpy as np

# %%
# image_filter = 'Bilder/*.jpg'
image_filter = 'Bilder/Aerial.jpg'

# %% [markdown]
# ## 1. Laden des Bildes

# %%
image_path = np.random.choice(glob.glob(image_filter))
image = imageio.imread(image_path)

image
# Out:
# Array([[199, 199, 199, ..., 230, 229, 232],
#        [199, 200, 200, ..., 231, 229, 231],
#        [200, 200, 201, ..., 232, 229, 229],
#        ...,
#        [225, 219, 205, ..., 227, 213, 196],
#        [213, 217, 219, ..., 215, 208, 211],
#        [198, 211, 231, ..., 198, 202, 217]], dtype=uint8)

# %% [markdown]
# ## 2. Bestimmung des Histogrammes
# Im Bild sind Grauwerte von mindestens 0 bis höchstens 255 vorhanden. Legen Sie eine Liste entsprechender Länge an, sodass die Grauwerte als Indizes verwendet werden können. Gehen Sie Pixel für Pixel durch das Bild, um das Histogramm zu berechnen. Verpacken Sie das Verfahren in einer Funktion!

# %%
def ex2_histogram(img):
    if(len(img.shape) != 2):
        print("img size error")
        return None
    histogram = {}
    for i1 in range(img.shape[0]):
        for i2 in range(img.shape[1]):
            if histogram.get(img[i1][i2]) is None:
                histogram[img[i1][i2]] = 0
            histogram[img[i1][i2]] += 1
    #cal max value
    maxValue = 0.0
    maxKey = -1
    for key in histogram:
        if histogram[key] > maxValue:
            maxValue = histogram[key]
            maxKey = key
    print(maxValue)
    print(maxKey)

    # normalize
    for key in histogram:
        histogram[key] = float(histogram[key]) / maxValue
    return histogram

# %% [markdown]
# ## 3. Darstellen des Histogrammes
# Zunächst wird die eben definierte Funktion zur Berechnung des Histogrammes aufgerufen.

# %%
image_histogram = ex2_histogram(image)
image_histogram
# Out:
# 14717
# 213
# {199: 0.4288917578310797,
#  198: 0.4278725283685534,
#  197: 0.4096622953047496,
#  200: 0.43446354555955696,
#  202: 0.43650200448460963,
#  201: 0.43337636746619557,
#  203: 0.4759801589997962,
#  206: 0.5825236121492152,
#  204: 0.4784942583406944,
#  205: 0.5429775090031936,
#  208: 0.645240198410002,
#  207: 0.6277094516545492,
#  209: 0.6412991778215669,
#  210: 0.6177210029217911,
#  211: 0.6151389549500578,
#  212: 0.6389209757423387,
#  213: 1.0,
#  214: 0.7640823537405721,
#  215: 0.7592580009512808,
#  216: 0.7513759597744105,
#  217: 0.9672487599374873,
#  137: 0.08649860705306787,
#  152: 0.11367805938710335,
#  136: 0.07895630903037304,
#  148: 0.09723449072501189,
#  144: 0.09071142216484337,
#  142: 0.09628320989332065,
#  118: 0.006319222667663247,
#  124: 0.07277298362437996,
#  141: 0.08479989128219066,
#  139: 0.08276143235713801,
#  125: 0.07290888088605015,
#  127: 0.06754093905007814,
#  150: 0.009580756947747503,
#  133: 0.07664605558198002,
#  134: 0.07943194944621866,
#  140: 0.008153835700210641,
#  123: 0.008357681592715906,
#  130: 0.0786165658761976,
#  131: 0.07603451790446422,
#  117: 0.06713324726506761,
#  99: 0.07284093225521505,
#  121: 0.06985119249847116,
#  135: 0.0071346062376843105,
#  113: 0.06726914452673778,
#  94: 0.08452809675885031,
#  132: 0.006998708976014133,
#  87: 0.10226268940680845,
#  119: 0.06794863083508867,
#  114: 0.0071346062376843105,
#  112: 0.007610246653529932,
#  108: 0.007270503499354488,
#  107: 0.0683563226200992,
#  78: 0.1372562342868791,
#  111: 0.06027043555072365,
#  89: 0.008357681592715906,
#  115: 0.0623768431066114,
#  109: 0.06264863762995175,
#  126: 0.0072025548685193995,
#  120: 0.006523068560168512,
#  104: 0.072025548685194,
#  90: 0.08778963103893457,
#  73: 0.19059590949242372,
#  102: 0.07005503839097642,
#  98: 0.006930760345179044,
#  83: 0.11469728884962968,
#  110: 0.006591017191003601,
#  96: 0.00509614731263165,
#  103: 0.007474349391859754,
#  72: 0.019025616633824828,
#  128: 0.007610246653529932,
#  86: 0.008425630223550995,
#  97: 0.07651015832030984,
#  60: 0.22348304681660663,
#  93: 0.0071346062376843105,
#  82: 0.008629476116056262,
#  116: 0.007542298022694843,
#  67: 0.24257661208126657,
#  79: 0.003737174695929877,
#  106: 0.004688455527621118,
#  48: 0.171638241489434,
#  0: 0.05823197662567099,
#  101: 0.004484609635115853,
#  77: 0.011619215872800162,
#  59: 0.017258952232112525,
#  74: 0.005911530882652715,
#  66: 0.022762791329754707,
#  95: 0.0029897397567439014,
#  84: 0.003261534280084256,
#  105: 0.002446150710063192,
#  47: 0.01528844193789495,
#  88: 0.003533328803424611,
#  91: 0.002514099340898281,
#  68: 0.007949989807705374,
#  100: 0.002649996602568458,
#  49: 0.0055038390976421825,
#  61: 0.006319222667663247,
#  1: 0.0007474349391859754}

# %% [markdown]
# Stellen Sie zu Vergleichszwecken zunächst das Bild dar:

# %%
plt.figure('Image')
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Verwenden Sie nun `matplotlib.pyplot`, um das Histogramm in Form eines Balkendiagrammes darzustellen.

# %%
plt.figure()
plt.axis([0,256,0,1])
plt.grid(True)

keys=image_histogram.keys()
values=image_histogram.values()
plt.bar(tuple(keys), tuple(values))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
